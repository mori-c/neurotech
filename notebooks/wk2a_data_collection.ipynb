# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

import csv
import matplotlib.pyplot as plt
import numpy as np
import pprint

# %%
with open('../data/stare_blink.csv') as csvfile:
    readCSV = csv.DictReader(csvfile)
    for row in readCSV:
        print(row)
        print()
# Out:
# OrderedDict([('l_ear', '815.934065934066'), ('l_forehead', '817.948717948718'), ('r_forehead', '843.7362637362637'), ('r_ear', '853.0036630036631'), ('ch5', 'nan'), ('ch6', 'nan')])
#
# OrderedDict([('l_ear', '818.7545787545788'), ('l_forehead', '818.3516483516484'), ('r_forehead', '842.1245421245421'), ('r_ear', '852.6007326007326'), ('ch5', 'nan'), ('ch6', 'nan')])
#
# OrderedDict([('l_ear', '811.9047619047619'), ('l_forehead', '819.1575091575091'), ('r_forehead', '843.7362637362637'), ('r_ear', '847.7655677655678'), ('ch5', 'nan'), ('ch6', 'nan')])
#
# OrderedDict([('l_ear', '811.9047619047619'), ('l_forehead', '818.7545787545788'), ('r_forehead', '844.5421245421246'), ('r_ear', '841.7216117216118'), ('ch5', 'nan'), ('ch6', 'nan')])
#
# OrderedDict([('l_ear', '810.2930402930403'), ('l_forehead', '820.3663003663004'), ('r_forehead', '847.3626373626374'), ('r_ear', '854.6153846153846'), ('ch5', 'nan'), ('ch6', 'nan')])
#
# ...

# %%
#  dtype = [('l_ear', 'float'), ('l_forehead', 'float'), ('r_forehead', 'float'), ('r_ear', 'float')]

l_ear = [float(row['l_ear'])]
print(l_ear)
print()

l_ear = [(row['l_ear'])]
print('l_ear:', l_ear)

l_forehead = [(row['l_forehead'])]
r_forehead = [(row['r_forehead'])]
r_ear = [(row['r_ear'])]

nodeValues = [l_ear, l_forehead, r_forehead, r_ear]
print('nodeValues: ', nodeValues)
type(nodeValues)
print()

# Decimal String
print('row["l_ear"]: ', row['l_ear'], type(row['l_ear']))
print()

# Numeric
print('l_ear: ', l_ear, type(l_ear))
# Out:
# [835.2747252747253]
#
# l_ear: ['835.2747252747253']
# nodeValues:  [['835.2747252747253'], ['832.4542124542124'], ['850.989010989011'], ['838.0952380952381']]
#
# row["l_ear"]:  835.2747252747253 <class 'str'>
#
# l_ear:  ['835.2747252747253'] <class 'list'>

# %%
# string = '835.2747252747253'
# num = 811.9047619047619
# concat = float(string) + num
# print(concat)

# list of strings
nodeValues = np.array([l_ear, l_forehead, r_forehead, r_ear])
print('nodeValues: ', nodeValues)
print()

# list of numerical 
# astype() = conver into floats
nodeFloatValues = nodeValues.astype(np.float)
print('nodeFloatValues: ', nodeFloatValues)

# https://is.gd/qPaNNI
# Out:
# nodeValues:  [['835.2747252747253']
#  ['832.4542124542124']
#  ['850.989010989011']
#  ['838.0952380952381']]
#
# nodeFloatValues:  [[835.27472527]
#  [832.45421245]
#  [850.98901099]
#  [838.0952381 ]]

# %%
# floatify = float(row['l_ear'])
floatify = [float(x) for x in nodeValues]

print('String into Float:', floatify)

# %%
# string = '835.2747252747253'
# num = 811.9047619047619
# concat = float(string) + num
# print(concat)

# str = ['1', '2', '3']
# int = [int(x) for x in str]
# print(int)
# Out:
# [1, 2, 3]
